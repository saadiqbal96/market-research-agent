# %% [markdown]
# # [SOLUTION] Udaplay Project - Part 01

# %% [markdown]
# ## Part 01 - Offline RAG
#
# In this part of the project, you'll build your VectorDB using Chroma.
#
# The data is inside folder `project/starter/games`. Each file will become a document in the collection you'll create.
# Example.:
# ```json
# {
#   "Name": "Gran Turismo",
#   "Platform": "PlayStation 1",
#   "Genre": "Racing",
#   "Publisher": "Sony Computer Entertainment",
#   "Description": "A realistic racing simulator featuring a wide array of cars and tracks, setting a new standard for the genre.",
#   "YearOfRelease": 1997
# }
# ```

# %% [markdown]
# ### Setup

# %%
# !pip install chromadb
import chromadb
# Out:
# Requirement already satisfied: chromadb in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (1.3.5)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (3.11.4)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: build>=1.0.3 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: rich>=10.11.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.38.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (2.12.5)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: typer>=0.9.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: importlib-resources in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: colorama in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: pyproject_hooks in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb) (2.3.0)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb) (8.7.0)
# Requirement already satisfied: anyio in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (4.12.0)
# Requirement already satisfied: httpcore==1.* in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: certifi in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.11.12)
# Requirement already satisfied: idna in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb) (3.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.5)
# Requirement already satisfied: urllib3<2.4.0,>=1.24.2 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.43.0)
# Requirement already satisfied: requests-oauthlib in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: sympy in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: coloredlogs in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-proto==1.39.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=1.9->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.2.1)
# Requirement already satisfied: typer-slim in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (0.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.12.0)
# Requirement already satisfied: filelock in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.0)
# Requirement already satisfied: shellingham in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pc\appdata\local\programs\python\python310\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the 'C:\Users\PC\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# Only needed for Udacity workspace
import importlib.util
import sys

# Check if 'pysqlite3' is available before importing
if importlib.util.find_spec("pysqlite3") is not None:
    import pysqlite3
    sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')

# %%
import os
import json
import chromadb
from chromadb.utils import embedding_functions
from dotenv import load_dotenv

# %%
# Load environment variables from .env file
# Make sure you have created a .env file with:
# OPENAI_API_KEY="YOUR_KEY"
# CHROMA_OPENAI_API_KEY="YOUR_KEY"
# TAVILY_API_KEY="YOUR_KEY"

load_dotenv()

# Verify that the API keys are loaded
assert os.getenv('OPENAI_API_KEY') is not None, "OPENAI_API_KEY not found in .env file"
assert os.getenv('TAVILY_API_KEY') is not None, "TAVILY_API_KEY not found in .env file"

print("✓ Environment variables loaded successfully")
# Out:
# ✓ Environment variables loaded successfully

# %% [markdown]
# ### VectorDB Instance

# %%
# Create a persistent ChromaDB client
# This will store the database in a folder called 'chromadb' in the current directory
chroma_client = chromadb.PersistentClient(path="chromadb")

print("✓ ChromaDB client created successfully")
# Out:
# ✓ ChromaDB client created successfully

# %% [markdown]
# ### Collection

# %%
# Set up the OpenAI embedding function
# This will use OpenAI's text-embedding-ada-002 model by default
embedding_fn = embedding_functions.OpenAIEmbeddingFunction(
    api_key=os.getenv('OPENAI_API_KEY'),
    model_name="text-embedding-ada-002"
)

print("✓ Embedding function configured")
# Out:
# ✓ Embedding function configured

# %%
# Try to get existing collection or create a new one
try:
    # Try to get existing collection
    collection = chroma_client.get_collection(
        name="udaplay",
        embedding_function=embedding_fn
    )
    print(f"✓ Loaded existing collection 'udaplay' with {collection.count()} documents")
except:
    # Create new collection if it doesn't exist
    collection = chroma_client.create_collection(
        name="udaplay",
        embedding_function=embedding_fn,
        metadata={"description": "Video game information database for UdaPlay agent"}
    )
    print("✓ Created new collection 'udaplay'")
# Out:
# ✓ Loaded existing collection 'udaplay' with 0 documents

# %% [markdown]
# ### Add documents

# %%
# Load and index all game data from JSON files
data_dir = "games"

# Check if collection is empty before adding documents
if collection.count() == 0:
    print("Adding documents to collection...")
    
    for file_name in sorted(os.listdir(data_dir)):
        if not file_name.endswith(".json"):
            continue

        file_path = os.path.join(data_dir, file_name)
        with open(file_path, "r", encoding="utf-8") as f:
            game = json.load(f)

        # Create a rich text representation for better semantic search
        content = f"[{game['Platform']}] {game['Name']} ({game['YearOfRelease']}) - {game['Description']}"

        # Use file name (like 001) as ID
        doc_id = os.path.splitext(file_name)[0]

        # Add document with metadata
        collection.add(
            ids=[doc_id],
            documents=[content],
            metadatas=[game]
        )
        print(f"  Added: {game['Name']} ({game['Platform']})")
    
    print(f"\n✓ Successfully added {collection.count()} documents to the collection")
else:
    print(f"✓ Collection already contains {collection.count()} documents")
# Out:
# Adding documents to collection...
#   Added: Gran Turismo (PlayStation 1)
#   Added: Grand Theft Auto: San Andreas (PlayStation 2)
#   Added: Gran Turismo 5 (PlayStation 3)
#   Added: Marvel's Spider-Man (PlayStation 4)
#   Added: Marvel's Spider-Man 2 (PlayStation 5)
#   Added: Pokémon Gold and Silver (Game Boy Color)
#   Added: Pokémon Ruby and Sapphire (Game Boy Advance)
#   Added: Super Mario World (Super Nintendo Entertainment System (SNES))
#   Added: Super Mario 64 (Nintendo 64)
#   Added: Super Smash Bros. Melee (GameCube)
#   Added: Wii Sports (Wii)
#   Added: Mario Kart 8 Deluxe (Nintendo Switch)
#   Added: Kinect Adventures! (Xbox 360)
#   Added: Minecraft (Xbox One)
#   Added: Halo Infinite (Xbox Series X|S)
#
# ✓ Successfully added 15 documents to the collection

# %% [markdown]
# ### Test the Vector Database

# %%
# Test semantic search with a sample query
test_query = "racing games for PlayStation"
results = collection.query(
    query_texts=[test_query],
    n_results=3
)

print(f"Query: '{test_query}'\n")
print("Top 3 Results:")
for i, (doc, metadata) in enumerate(zip(results['documents'][0], results['metadatas'][0]), 1):
    print(f"\n{i}. {metadata['Name']}")
    print(f"   Platform: {metadata['Platform']}")
    print(f"   Year: {metadata['YearOfRelease']}")
    print(f"   Genre: {metadata['Genre']}")
# Out:
# Query: 'racing games for PlayStation'
#
# Top 3 Results:
#
# 1. Gran Turismo
#    Platform: PlayStation 1
#    Year: 1997
#    Genre: Racing
#
# 2. Gran Turismo 5
#    Platform: PlayStation 3
#    Year: 2010
#    Genre: Racing
#
# 3. Grand Theft Auto: San Andreas
#    Platform: PlayStation 2
#    Year: 2004
#    Genre: Action-adventure

# %% [markdown]
# ## Summary
#
# In this notebook, we:
# 1. ✓ Set up ChromaDB as a persistent vector database
# 2. ✓ Configured OpenAI embeddings for semantic search
# 3. ✓ Created a collection to store game information
# 4. ✓ Loaded and indexed all game data from JSON files
# 5. ✓ Tested the semantic search functionality
#
# The vector database is now ready to be used in Part 2 for the AI agent implementation.
